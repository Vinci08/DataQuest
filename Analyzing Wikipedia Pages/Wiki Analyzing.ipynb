# %% [markdown]
# # Review the Folder wiki

# %%
import os

# os.listdir('wiki') - use this to list all files in wiki folder

# Count up and display the number of files in the wiki folder

count_wiki_folder = len(os.listdir('wiki'))

count_wiki_folder
# Out:
# 999

# %%
with open("wiki/Zehut.html", encoding="utf8") as f:
    print(f.read())
# Out:
# <!DOCTYPE html>
# <html class="client-nojs" lang="en" dir="ltr">
# <head>
# <meta charset="UTF-8"/>
# <title>Zehut - Wikipedia</title>
# <script>document.documentElement.className = document.documentElement.className.replace( /(^|\s)client-nojs(\s|$)/, "$1client-js$2" );</script>
# <script>(window.RLQ=window.RLQ||[]).push(function(){mw.config.set({"wgCanonicalNamespace":"","wgCanonicalSpecialPageName":false,"wgNamespaceNumber":0,"wgPageName":"Zehut","wgTitle":"Zehut","wgCurRevisionId":765862038,"wgRevisionId":765862038,"wgArticleId":49635088,"wgIsArticle":true,"wgIsRedirect":false,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":["Articles with a promotional tone from October 2016","All articles with a promotional tone","Pages using deprecated image syntax","All articles with unsourced statements","Articles with unsourced statements from February 2017","2015 establishments in Israel","Liberal parties in Israel","Political parties established in 2015","Zionist political parties in Israel"],"wgBreakFrames":false,"wgPageContentLanguage":"en","wgPageContentModel":"wikitext","wgSeparatorTransformTable":["",""],"wgDigitTransformTable":["",""],"wgDefaultDateFormat":"dmy","wgMonthNames":["","January","February","March","April","May","June","July","August","September","October","November","December"],"wgMonthNamesShort":["","Jan","Feb","Mar","Apr","May","Jun","Jul","Aug","Sep","Oct","Nov","Dec"],"wgRelevantPageName":"Zehut","wgRelevantArticleId":49635088,"wgRequestId":"WLLQ6gpAEKsAACX@ZiEAAAAM","wgIsProbablyEditable":true,"wgRestrictionEdit":[],"wgRestrictionMove":[],"wgFlaggedRevsParams":{"tags":{}},"wgStableRevisionId":null,"wgWikiEditorEnabledModules":{"toolbar":true,"dialogs":true,"preview":false,"publish":false},"wgBetaFeaturesFeatures":[],"wgMediaViewerOnClick":true,"wgMediaViewerEnabledByDefault":true,"wgPopupsShouldSendModuleToUser":false,"wgPopupsConflictsWithNavPopupGadget":false,"wgVisualEditor":{"pageLanguageCode":"en","pageLanguageDir":"ltr","usePageImages":true,"usePageDescriptions":true},"wgPreferredVariant":"en","wgMFDisplayWikibaseDescriptions":{"search":true,"nearby":true,"watchlist":true,"tagline":true},"wgRelatedArticles":null,"wgRelatedArticlesBetaFeatureEnabled":false,"wgRelatedArticlesUseCirrusSearch":true,"wgRelatedArticlesOnlyUseCirrusSearch":false,"wgULSCurrentAutonym":"English","wgNoticeProject":"wikipedia","wgCentralNoticeCookiesToDelete":[],"wgCentralNoticeCategoriesUsingLegacy":["Fundraising","fundraising"],"wgCategoryTreePageCategoryOptions":"{\"mode\":0,\"hideprefix\":20,\"showcount\":true,\"namespaces\":false}","wgWikibaseItemId":"Q23304767","wgCentralAuthMobileDomain":false,"wgVisualEditorToolbarScrollOffset":0,"wgEditSubmitButtonLabelPublish":false});mw.loader.state({"ext.globalCssJs.user.styles":"ready","ext.globalCssJs.site.styles":"ready","site.styles":"ready","noscript":"ready","user.styles":"ready","user":"ready","user.options":"loading","user.tokens":"loading","ext.cite.styles":"ready","wikibase.client.init":"ready","ext.visualEditor.desktopArticleTarget.noscript":"ready","ext.uls.interlanguage":"ready","ext.wikimediaBadges":"ready","mediawiki.legacy.shared":"ready","mediawiki.legacy.commonPrint":"ready","mediawiki.sectionAnchor":"ready","mediawiki.skinning.interface":"ready","skins.vector.styles":"ready","ext.globalCssJs.user":"ready","ext.globalCssJs.site":"ready"});mw.loader.implement("user.options@0j3lz3q",function($,jQuery,require,module){mw.user.options.set({"variant":"en"});});mw.loader.implement("user.tokens@1dqfd7l",function ( $, jQuery, require, module ) {
# mw.user.tokens.set({"editToken":"+\\","patrolToken":"+\\","watchToken":"+\\","csrfToken":"+\\"});/*@nomin*/;
#
# });mw.loader.load(["ext.cite.a11y","mediawiki.action.view.postEdit","site","mediawiki.page.startup","mediawiki.user","mediawiki.hidpi","mediawiki.page.ready","mediawiki.legacy.wikibits","mediawiki.searchSuggest","ext.gadget.teahouse","ext.gadget.ReferenceTooltips","ext.gadget.watchlist-notice","ext.gadget.DRN-wizard","ext.gadget.charinsert","ext.gadget.refToolbar","ext.gadget.extra-toolbar-buttons","ext.gadget.switcher","ext.gadget.featured-articles-links","ext.centralauth.centralautologin","mmv.head","mmv.bootstrap.autostart","ext.visualEditor.desktopArticleTarget.init","ext.visualEditor.targetLoader","ext.eventLogging.subscriber","ext.wikimediaEvents","ext.navigationTiming","ext.uls.eventlogger","ext.uls.init","ext.uls.interface","ext.quicksurveys.init","ext.centralNotice.geoIP","ext.centralNotice.startUp","skins.vector.js"]);});</script>
# <link rel="stylesheet" href="/w/load.php?debug=false&amp;lang=en&amp;modules=ext.cite.styles%7Cext.uls.interlanguage%7Cext.visualEditor.desktopArticleTarget.noscript%7Cext.wikimediaBadges%7Cmediawiki.legacy.commonPrint%2Cshared%7Cmediawiki.sectionAnchor%7Cmediawiki.skinning.interface%7Cskins.vector.styles%7Cwikibase.client.init&amp;only=styles&amp;skin=vector"/>
# <script async="" src="/w/load.php?debug=false&amp;lang=en&amp;modules=startup&amp;only=scripts&amp;skin=vector"></script>
# <meta name="ResourceLoaderDynamicStyles" content=""/>
# <link rel="stylesheet" href="/w/load.php?debug=false&amp;lang=en&amp;modules=site.styles&amp;only=styles&amp;skin=vector"/>
# <meta name="generator" content="MediaWiki 1.29.0-wmf.13"/>
# <meta name="referrer" content="origin-when-cross-origin"/>
# <meta property="og:image" content="https://upload.wikimedia.org/wikipedia/commons/4/4b/Zehutlogo.png"/>
# <link rel="alternate" href="android-app://org.wikipedia/http/en.m.wikipedia.org/wiki/Zehut"/>
# <link rel="alternate" type="application/x-wiki" title="Edit this page" href="/w/index.php?title=Zehut&amp;action=edit"/>
# <link rel="edit" title="Edit this page" href="/w/index.php?title=Zehut&amp;action=edit"/>
# <link rel="apple-touch-icon" href="/static/apple-touch/wikipedia.png"/>
# <link rel="shortcut icon" href="/static/favicon/wikipedia.ico"/>
# <link rel="search" type="application/opensearchdescription+xml" href="/w/opensearch_desc.php" title="Wikipedia (en)"/>
# <link rel="EditURI" type="application/rsd+xml" href="//en.wikipedia.org/w/api.php?action=rsd"/>
# <link rel="copyright" href="//creativecommons.org/licenses/by-sa/3.0/"/>
# <link rel="canonical" href="https://en.wikipedia.org/wiki/Zehut"/>
# <link rel="dns-prefetch" href="//login.wikimedia.org"/>
# <link rel="dns-prefetch" href="//meta.wikimedia.org" />
# </head>
# <body class="mediawiki ltr sitedir-ltr mw-hide-empty-elt ns-0 ns-subject page-Zehut rootpage-Zehut skin-vector action-view">		<div id="mw-page-base" class="noprint"></div>
# 		<div id="mw-head-base" class="noprint"></div>
# 		<div id="content" class="mw-body" role="main">
# 			<a id="top"></a>
#
# 							<div id="siteNotice"><!-- CentralNotice --></div>
# 						<div class="mw-indicators">
# </div>
# 			<h1 id="firstHeading" class="firstHeading" lang="en">Zehut</h1>
# 									<div id="bodyContent" class="mw-body-content">
# 									<div id="siteSub">From Wikipedia, the free encyclopedia</div>
# 								<div id="contentSub"></div>
# 												<div id="jump-to-nav" class="mw-jump">
# 					Jump to:					<a href="#mw-head">navigation</a>, 					<a href="#p-search">search</a>
# 				</div>
# 				<div id="mw-content-text" lang="en" dir="ltr" class="mw-content-ltr"><div class="boilerplate metadata plainlinks" id="tfd" style="background-color: transparent; padding: 0; font-size:xx-small; color:#000000; text-align: center; border-bottom:1px solid #AAAAAA;">‹ The <a href="/wiki/Help:Template" title="Help:Template">template</a> below (<i><a href="/wiki/Template:Advert" title="Template:Advert">Advert</a></i>) is being considered for merging. See <a href="/wiki/Wikipedia:Templates_for_discussion/Log/2017_February_21#Template:Advert" title="Wikipedia:Templates for discussion/Log/2017 February 21">templates for discussion</a> to help reach a consensus.›</div>
# <table class="plainlinks metadata ambox ambox-content ambox-Advert" role="presentation">
# <tr>
# <td class="mbox-image">
# <div style="width:52px"><img alt="" src="//upload.wikimedia.org/wikipedia/commons/thumb/b/b4/Ambox_important.svg/40px-Ambox_important.svg.png" width="40" height="40" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/b/b4/Ambox_important.svg/60px-Ambox_important.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/b/b4/Ambox_important.svg/80px-Ambox_important.svg.png 2x" data-file-width="40" data-file-height="40" /></div>
# </td>
# <td class="mbox-text"><span class="mbox-text-span">This article <b>contains content that is written like <a href="/wiki/Wikipedia:What_Wikipedia_is_not#Wikipedia_is_not_a_soapbox_or_means_of_promotion" title="Wikipedia:What Wikipedia is not">an advertisement</a></b>. <span class="hide-when-compact">Please help <a class="external text" href="//en.wikipedia.org/w/index.php?title=Zehut&amp;action=edit">improve it</a> by removing <a href="/wiki/Wikipedia:Spam" title="Wikipedia:Spam">promotional content</a> and inappropriate <a href="/wiki/Wikipedia:External_links" title="Wikipedia:External links">external links</a>, and by adding encyclopedic content written from a <a href="/wiki/Wikipedia:Neutral_point_of_view" title="Wikipedia:Neutral point of view">neutral point of view</a>.</span> <small><i>(October 2016)</i></small> <small class="hide-when-compact"><i>(<a href="/wiki/Help:Maintenance_template_removal" title="Help:Maintenance template removal">Learn how and when to remove this template message</a>)</i></small></span></td>
# </tr>
# </table>
# <table class="infobox vcard" style="width:22em">
# <tr>
# <th colspan="2" style="text-align:center;font-size:125%;font-weight:bold;padding-top:0; padding-bottom:0;">
# <div style="padding-top:0.3em; padding-bottom:0.3em; border-top:2px solid #005693; border-bottom:2px solid #005693; line-height: 1;"><span class="fn org">Zehut</span><br />
# <span class="nickname" lang="he" style="font-size: 0.8em;">זהות</span></div>
# </th>
# </tr>
# <tr>
# <td colspan="2" class="logo" style="text-align:center;padding-top:.4em;padding-bottom:.3em;"><a href="/wiki/File:Zehutlogo.png" class="image"><img alt="Zehutlogo.png" src="//upload.wikimedia.org/wikipedia/commons/4/4b/Zehutlogo.png" width="250" height="114" data-file-width="220" data-file-height="100" /></a></td>
# </tr>
# <tr>
# <th scope="row" style="line-height:1.3em;">Leader</th>
# <td class="agent" style="line-height:1.3em;"><a href="/wiki/Moshe_Feiglin" title="Moshe Feiglin">Moshe Feiglin</a></td>
# </tr>
# <tr>
# <th scope="row" style="line-height:1.3em;">Founded</th>
# <td style="line-height:1.3em;">March 2015<span style="display:none">&#160;(<span class="dtstart">2015-03</span>)</span></td>
# </tr>
# <tr>
# <th scope="row" style="line-height:1.3em;"><a href="/wiki/List_of_political_ideologies" title="List of political ideologies">Ideology</a></th>
# <td class="category" style="line-height:1.3em;"><a href="/wiki/Libertarian_conservatism" title="Libertarian conservatism">Libertarian conservatism</a><sup class="noprint Inline-Template Template-Fact" style="white-space:nowrap;">[<i><a href="/wiki/Wikipedia:Citation_needed" title="Wikipedia:Citation needed"><span title="This claim needs references to reliable sources. (February 2017)">citation needed</span></a></i>]</sup><br />
# <a href="/wiki/Economic_liberalism" title="Economic liberalism">Economic liberalism</a><br />
# <a href="/wiki/National_liberalism" title="National liberalism">National liberalism</a><br />
# <a href="/wiki/Zionism" title="Zionism">Zionism</a></td>
# </tr>
# <tr>
# <th scope="row" style="line-height:1.3em;"><a href="/wiki/Political_spectrum" title="Political spectrum">Political&#160;position</a></th>
# <td class="category" style="line-height:1.3em;"><a href="/wiki/Right-wing" class="mw-redirect" title="Right-wing">right-wing</a><sup class="noprint Inline-Template Template-Fact" style="white-space:nowrap;">[<i><a href="/wiki/Wikipedia:Citation_needed" title="Wikipedia:Citation needed"><span title="This claim needs references to reliable sources. (February 2017)">citation needed</span></a></i>]</sup></td>
# </tr>
# <tr>
# <th colspan="2" style="text-align:center;line-height: 0.8em; padding-top:0.5em; padding-bottom:0;">Website</th>
# </tr>
# <tr>
# <td colspan="2" style="text-align:center;line-height:1.3em;"><span class="url"><a rel="nofollow" class="external text" href="http://www.zehutinternational.com">www<wbr />.zehutinternational<wbr />.com</a></span></td>
# </tr>
# <tr>
# <td colspan="2" style="text-align:center;padding-top:0;">
# <div class="plainlist" style="line-height:1.3em; padding-top:0.3em; border-top:2px solid #005693;">
# <ul>
# <li><a href="/wiki/Politics_of_Israel" title="Politics of Israel">Politics of Israel</a></li>
# <li><a href="/wiki/List_of_political_parties_in_Israel" title="List of political parties in Israel">Political parties</a></li>
# <li><a href="/wiki/Elections_in_Israel" title="Elections in Israel">Elections</a></li>
# </ul>
# </div>
# </td>
# </tr>
# </table>
# <p><b>Zehut</b> (<a href="/wiki/Hebrew_language" title="Hebrew language">Hebrew</a>: זֶהוּת, lit. <i>Identity</i>) is an <a href="/wiki/Israel" title="Israel">Israeli</a> <a href="/wiki/Political_party" title="Political party">political party</a> founded by former Deputy Speaker of the <a href="/wiki/Knesset" title="Knesset">Knesset</a> and "<a href="/wiki/Zo_Artzeinu" title="Zo Artzeinu">Zo Artzeinu</a>" co-founder <a href="/wiki/Moshe_Feiglin" title="Moshe Feiglin">Moshe Feiglin</a> in 2015.<sup id="cite_ref-1" class="reference"><a href="#cite_note-1">[1]</a></sup> The party advocates "the return of the country to the Jewish people and leading the State of Israel through authentic Jewish values."<sup id="cite_ref-2" class="reference"><a href="#cite_note-2">[2]</a></sup></p>
# <h2><span class="mw-headline" id="History">History</span><span class="mw-editsection"><span class="mw-editsection-bracket">[</span><a href="/w/index.php?title=Zehut&amp;action=edit&amp;section=1" title="Edit section: History">edit</a><span class="mw-editsection-bracket">]</span></span></h2>
# <p>The roots of Zehut lie in the <a href="/wiki/Manhigut_Yehudit" title="Manhigut Yehudit">Jewish Leadership</a> movement within the <a href="/wiki/Likud_party" class="mw-redirect" title="Likud party">Likud party</a>, established in 1995 by Moshe Feiglin in order to seize the country’s leadership through the ruling Likud party. In the 2013 elections Feiglin was elected for the Likud list for the Knesset and served as deputy speaker of the 19th Knesset.<sup id="cite_ref-3" class="reference"><a href="#cite_note-3">[3]</a></sup></p>
# <p>Prior to the 2012 elections, Feiglin announced his intention of competing for leadership of the Likud, but left the race after Prime Minister <a href="/wiki/Benjamin_Netanyahu" title="Benjamin Netanyahu">Binyamin Netanyahu</a> took active steps to block Feiglin's advancement.<sup id="cite_ref-4" class="reference"><a href="#cite_note-4">[4]</a></sup> This led Feiglin to the conclusion that it would be impossible to affect any political changes while acting within the Likud party. In 2015, he left the Likud to form Zehut. The party was officially registered later that year.<sup id="cite_ref-5" class="reference"><a href="#cite_note-5">[5]</a></sup> <sup id="cite_ref-6" class="reference"><a href="#cite_note-6">[6]</a></sup></p>
# <h2><span class="mw-headline" id="Platform">Platform</span><span class="mw-editsection"><span class="mw-editsection-bracket">[</span><a href="/w/index.php?title=Zehut&amp;action=edit&amp;section=2" title="Edit section: Platform">edit</a><span class="mw-editsection-bracket">]</span></span></h2>
# <p>The goals of Zehut include:<sup id="cite_ref-7" class="reference"><a href="#cite_note-7">[7]</a></sup></p>
# <ul>
# <li>Opposition to coercion of all kinds: religious, anti-religious, economic, cultural, or educational.<sup id="cite_ref-8" class="reference"><a href="#cite_note-8">[8]</a></sup></li>
# <li>Small government and the minimization of state intervention in the life and liberty of private citizens.</li>
# <li>Reforming education in Israel to follow the <a href="/wiki/School_voucher" title="School voucher">school voucher</a> system.<sup id="cite_ref-9" class="reference"><a href="#cite_note-9">[9]</a></sup></li>
# <li>Reduction of housing prices through land privatization, removal of planning and building committees, and increased construction in Judea and Samaria.</li>
# <li>Gradual transition to a professional volunteer army.</li>
# <li>Jewish sovereignty in all parts of the Land of Israel and encouragement of voluntary emigration of the Arabs in Judea and Samaria. Arabs who choose to remain may do so as permanent residents after proving their loyalty to the Jewish state. The option of receiving Israeli citizenship will be given after a protracted cooling-off period and compliance with conditions to be specified.<sup id="cite_ref-10" class="reference"><a href="#cite_note-10">[10]</a></sup></li>
# <li>Gradual legalization of cannabis, based on the successful model employed in Colorado and other states in the US.<sup id="cite_ref-11" class="reference"><a href="#cite_note-11">[11]</a></sup></li>
# </ul>
# <h2><span class="mw-headline" id="References">References</span><span class="mw-editsection"><span class="mw-editsection-bracket">[</span><a href="/w/index.php?title=Zehut&amp;action=edit&amp;section=3" title="Edit section: References">edit</a><span class="mw-editsection-bracket">]</span></span></h2>
# <div class="reflist" style="list-style-type: decimal;">
# <ol class="references">
# <li id="cite_note-1"><span class="mw-cite-backlink"><b><a href="#cite_ref-1">^</a></b></span> <span class="reference-text"><cite class="citation web"><a rel="nofollow" class="external text" href="http://www.israelnationalnews.com/News/News.aspx/198253#.Vv7Vxfl97IU">"Feiglin Registers 'Zehut' Party"</a>. <i>Arutz Sheva</i><span class="reference-accessdate">. Retrieved <span class="nowrap">2016-04-01</span></span>.</cite><span title="ctx_ver=Z39.88-2004&amp;rfr_id=info%3Asid%2Fen.wikipedia.org%3AZehut&amp;rft.atitle=Feiglin+Registers+%27Zehut%27+Party&amp;rft.genre=unknown&amp;rft_id=http%3A%2F%2Fwww.israelnationalnews.com%2FNews%2FNews.aspx%2F198253%23.Vv7Vxfl97IU&amp;rft.jtitle=Arutz+Sheva&amp;rft_val_fmt=info%3Aofi%2Ffmt%3Akev%3Amtx%3Ajournal" class="Z3988"><span style="display:none;">&#160;</span></span></span></li>
# <li id="cite_note-2"><span class="mw-cite-backlink"><b><a href="#cite_ref-2">^</a></b></span> <span class="reference-text"><cite class="citation web"><a rel="nofollow" class="external text" href="http://www.zehutinternational.com/about-zehut.html">"About Zehut"</a>. <i>www.zehutinternational.com</i><span class="reference-accessdate">. Retrieved <span class="nowrap">2016-04-01</span></span>.</cite><span title="ctx_ver=Z39.88-2004&amp;rfr_id=info%3Asid%2Fen.wikipedia.org%3AZehut&amp;rft.atitle=About+Zehut&amp;rft.genre=unknown&amp;rft_id=http%3A%2F%2Fwww.zehutinternational.com%2Fabout-zehut.html&amp;rft.jtitle=www.zehutinternational.com&amp;rft_val_fmt=info%3Aofi%2Ffmt%3Akev%3Amtx%3Ajournal" class="Z3988"><span style="display:none;">&#160;</span></span></span></li>
# <li id="cite_note-3"><span class="mw-cite-backlink"><b><a href="#cite_ref-3">^</a></b></span> <span class="reference-text"><cite class="citation web"><a rel="nofollow" class="external text" href="http://jpupdates.com/2015/02/26/moshe-feiglin-establishes-new-party/">"Former Likud MK Moshe Feiglin Establishes New Political Party |"</a>. <i>jpupdates.com</i><span class="reference-accessdate">. Retrieved <span class="nowrap">2016-04-01</span></span>.</cite><span title="ctx_ver=Z39.88-2004&amp;rfr_id=info%3Asid%2Fen.wikipedia.org%3AZehut&amp;rft.atitle=Former+Likud+MK+Moshe+Feiglin+Establishes+New+Political+Party+++%7C&amp;rft.genre=unknown&amp;rft_id=http%3A%2F%2Fjpupdates.com%2F2015%2F02%2F26%2Fmoshe-feiglin-establishes-new-party%2F&amp;rft.jtitle=jpupdates.com&amp;rft_val_fmt=info%3Aofi%2Ffmt%3Akev%3Amtx%3Ajournal" class="Z3988"><span style="display:none;">&#160;</span></span></span></li>
# <li id="cite_note-4"><span class="mw-cite-backlink"><b><a href="#cite_ref-4">^</a></b></span> <span class="reference-text"><cite class="citation web"><a rel="nofollow" class="external text" href="http://www.ynetnews.com/articles/0,7340,L-3637281,00.html">"Feiglin won't appeal bump to 36th spot"</a>. <i>ynet</i><span class="reference-accessdate">. Retrieved <span class="nowrap">2016-04-01</span></span>.</cite><span title="ctx_ver=Z39.88-2004&amp;rfr_id=info%3Asid%2Fen.wikipedia.org%3AZehut&amp;rft.atitle=Feiglin+won%27t+appeal+bump+to+36th+spot&amp;rft.genre=unknown&amp;rft_id=http%3A%2F%2Fwww.ynetnews.com%2Farticles%2F0%2C7340%2CL-3637281%2C00.html&amp;rft.jtitle=ynet&amp;rft_val_fmt=info%3Aofi%2Ffmt%3Akev%3Amtx%3Ajournal" class="Z3988"><span style="display:none;">&#160;</span></span></span></li>
# <li id="cite_note-5"><span class="mw-cite-backlink"><b><a href="#cite_ref-5">^</a></b></span> <span class="reference-text"><cite class="citation web"><a rel="nofollow" class="external text" href="http://www.jpost.com/Israel-News/Politics-And-Diplomacy/Feiglin-to-register-new-political-party-395625">"Feiglin to register new political party"</a>. <i>Jerusalem Post</i>.</cite><span title="ctx_ver=Z39.88-2004&amp;rfr_id=info%3Asid%2Fen.wikipedia.org%3AZehut&amp;rft.atitle=Feiglin+to+register+new+political+party&amp;rft.genre=unknown&amp;rft_id=http%3A%2F%2Fwww.jpost.com%2FIsrael-News%2FPolitics-And-Diplomacy%2FFeiglin-to-register-new-political-party-395625&amp;rft.jtitle=Jerusalem+Post&amp;rft_val_fmt=info%3Aofi%2Ffmt%3Akev%3Amtx%3Ajournal" class="Z3988"><span style="display:none;">&#160;</span></span></span></li>
# <li id="cite_note-6"><span class="mw-cite-backlink"><b><a href="#cite_ref-6">^</a></b></span> <span class="reference-text"><cite class="citation web"><a rel="nofollow" class="external text" href="http://www.haaretz.com/israel-news/.premium-1.650650">"Feiglin Establishing New Party for Next Knesset Election"</a>. <i>Haaretz.com</i>.</cite><span title="ctx_ver=Z39.88-2004&amp;rfr_id=info%3Asid%2Fen.wikipedia.org%3AZehut&amp;rft.atitle=Feiglin+Establishing+New+Party+for+Next+Knesset+Election&amp;rft.genre=unknown&amp;rft_id=http%3A%2F%2Fwww.haaretz.com%2Fisrael-news%2F.premium-1.650650&amp;rft.jtitle=Haaretz.com&amp;rft_val_fmt=info%3Aofi%2Ffmt%3Akev%3Amtx%3Ajournal" class="Z3988"><span style="display:none;">&#160;</span></span></span></li>
# <li id="cite_note-7"><span class="mw-cite-backlink"><b><a href="#cite_ref-7">^</a></b></span> <span class="reference-text"><cite class="citation web"><a rel="nofollow" class="external text" href="http://www.queensjewishlink.com/qjl/israels-newest-political-party-2/">"Israel's Newest Political Party"</a>. <i>Queens Jewish Link</i><span class="reference-accessdate">. Retrieved <span class="nowrap">2016-04-01</span></span>.</cite><span title="ctx_ver=Z39.88-2004&amp;rfr_id=info%3Asid%2Fen.wikipedia.org%3AZehut&amp;rft.atitle=Israel%99s+Newest+Political+Party&amp;rft.genre=unknown&amp;rft_id=http%3A%2F%2Fwww.queensjewishlink.com%2Fqjl%2Fisraels-newest-political-party-2%2F&amp;rft.jtitle=Queens+Jewish+Link&amp;rft_val_fmt=info%3Aofi%2Ffmt%3Akev%3Amtx%3Ajournal" class="Z3988"><span style="display:none;">&#160;</span></span></span></li>
# <li id="cite_note-8"><span class="mw-cite-backlink"><b><a href="#cite_ref-8">^</a></b></span> <span class="reference-text"><cite class="citation web"><a rel="nofollow" class="external text" href="http://www.zehutinternational.com/about-zehut.html">"About Zehut"</a>. <i>www.zehutinternational.com</i><span class="reference-accessdate">. Retrieved <span class="nowrap">2016-04-01</span></span>.</cite><span title="ctx_ver=Z39.88-2004&amp;rfr_id=info%3Asid%2Fen.wikipedia.org%3AZehut&amp;rft.atitle=About+Zehut&amp;rft.genre=unknown&amp;rft_id=http%3A%2F%2Fwww.zehutinternational.com%2Fabout-zehut.html&amp;rft.jtitle=www.zehutinternational.com&amp;rft_val_fmt=info%3Aofi%2Ffmt%3Akev%3Amtx%3Ajournal" class="Z3988"><span style="display:none;">&#160;</span></span></span></li>
# <li id="cite_note-9"><span class="mw-cite-backlink"><b><a href="#cite_ref-9">^</a></b></span> <span class="reference-text"><cite class="citation web">Feiglin, Moshe. <a rel="nofollow" class="external text" href="http://www.jewishpress.com/indepth/columns/moshe-feiglin/israel-needs-school-vouchers/2015/05/31/">"Israel Needs School Vouchers"</a>. <i>The Jewish Press</i><span class="reference-accessdate">. Retrieved <span class="nowrap">2016-04-01</span></span>.</cite><span title="ctx_ver=Z39.88-2004&amp;rfr_id=info%3Asid%2Fen.wikipedia.org%3AZehut&amp;rft.atitle=Israel+Needs+School+Vouchers&amp;rft.aufirst=Moshe&amp;rft.aulast=Feiglin&amp;rft.genre=unknown&amp;rft_id=http%3A%2F%2Fwww.jewishpress.com%2Findepth%2Fcolumns%2Fmoshe-feiglin%2Fisrael-needs-school-vouchers%2F2015%2F05%2F31%2F&amp;rft.jtitle=The+Jewish+Press&amp;rft_val_fmt=info%3Aofi%2Ffmt%3Akev%3Amtx%3Ajournal" class="Z3988"><span style="display:none;">&#160;</span></span></span></li>
# <li id="cite_note-10"><span class="mw-cite-backlink"><b><a href="#cite_ref-10">^</a></b></span> <span class="reference-text"><cite class="citation web"><a rel="nofollow" class="external text" href="http://www.voiceofisrael.com/if-moshe-feiglin-were-prime-minister/">"If Moshe Feiglin were Prime Minister"</a>. <i>voiceofisrael.com</i>.</cite><span title="ctx_ver=Z39.88-2004&amp;rfr_id=info%3Asid%2Fen.wikipedia.org%3AZehut&amp;rft.atitle=If+Moshe+Feiglin+were+Prime+Minister&amp;rft.genre=unknown&amp;rft_id=http%3A%2F%2Fwww.voiceofisrael.com%2Fif-moshe-feiglin-were-prime-minister%2F&amp;rft.jtitle=voiceofisrael.com&amp;rft_val_fmt=info%3Aofi%2Ffmt%3Akev%3Amtx%3Ajournal" class="Z3988"><span style="display:none;">&#160;</span></span></span></li>
# <li id="cite_note-11"><span class="mw-cite-backlink"><b><a href="#cite_ref-11">^</a></b></span> <span class="reference-text"><cite class="citation web"><a rel="nofollow" class="external text" href="http://www.jta.org/2013/11/19/life-religion/sometimes-theres-a-man-feiglin-leads-charge-for-israeli-marijuana-legalization">"Likud's Moshe Feiglin: Cool on Palestinians, hot for pot"</a>. <i>Jewish Telegraphic Agency</i><span class="reference-accessdate">. Retrieved <span class="nowrap">2016-04-01</span></span>.</cite><span title="ctx_ver=Z39.88-2004&amp;rfr_id=info%3Asid%2Fen.wikipedia.org%3AZehut&amp;rft.atitle=Likud%99s+Moshe+Feiglin%3A+Cool+on+Palestinians%2C+hot+for+pot&amp;rft.genre=unknown&amp;rft_id=http%3A%2F%2Fwww.jta.org%2F2013%2F11%2F19%2Flife-religion%2Fsometimes-theres-a-man-feiglin-leads-charge-for-israeli-marijuana-legalization&amp;rft.jtitle=Jewish+Telegraphic+Agency&amp;rft_val_fmt=info%3Aofi%2Ffmt%3Akev%3Amtx%3Ajournal" class="Z3988"><span style="display:none;">&#160;</span></span></span></li>
# </ol>
# </div>
# <ul>
# <li class="mw-empty-elt"></li>
# <li class="mw-empty-elt"></li>
# <li class="mw-empty-elt"></li>
# <li class="mw-empty-elt"></li>
# </ul>
#
#
# <!--
# NewPP limit report
# Parsed by mw1220
# Cached time: 20170221103941
# Cache expiry: 2592000
# Dynamic content: false
# CPU time usage: 0.212 seconds
# Real time usage: 0.271 seconds
# Preprocessor visited node count: 1806/1000000
# Preprocessor generated node count: 0/1500000
# Post‐expand include size: 35657/2097152 bytes
# Template argument size: 2804/2097152 bytes
# Highest expansion depth: 21/40
# Expensive parser function count: 5/500
# Lua time usage: 0.101/10.000 seconds
# Lua memory usage: 4.72 MB/50 MB
# -->
# <!--
# Transclusion expansion time report (%,ms,calls,template)
# 100.00%  239.293      1 -total
#  45.05%  107.811      1 Template:Infobox_political_party
#  38.10%   91.176      1 Template:Infobox
#  32.95%   78.838      1 Template:Reflist
#  24.72%   59.158     11 Template:Cite_web
#  19.58%   46.863      1 Template:Advert
#  14.60%   34.928      2 Template:Citation_needed
#  13.27%   31.763      2 Template:Fix
#  12.11%   28.985      1 Template:Ambox
#   7.81%   18.682      2 Template:Delink
# -->
#
# <!-- Saved in parser cache with key enwiki:pcache:idhash:49635088-0!*!0!default!!*!4!* and timestamp 20170221103941 and revision id 765862038
#  -->
# <noscript><img src="//en.wikipedia.org/wiki/Special:CentralAutoLogin/start?type=1x1" alt="" title="" width="1" height="1" style="border: none; position: absolute;" /></noscript></div>					<div class="printfooter">
# 						Retrieved from "<a dir="ltr" href="https://en.wikipedia.org/w/index.php?title=Zehut&amp;oldid=765862038">https://en.wikipedia.org/w/index.php?title=Zehut&amp;oldid=765862038</a>"					</div>
# 				<div id="catlinks" class="catlinks" data-mw="interface"><div id="mw-normal-catlinks" class="mw-normal-catlinks"><a href="/wiki/Help:Category" title="Help:Category">Categories</a>: <ul><li><a href="/wiki/Category:2015_establishments_in_Israel" title="Category:2015 establishments in Israel">2015 establishments in Israel</a></li><li><a href="/wiki/Category:Liberal_parties_in_Israel" title="Category:Liberal parties in Israel">Liberal parties in Israel</a></li><li><a href="/wiki/Category:Political_parties_established_in_2015" title="Category:Political parties established in 2015">Political parties established in 2015</a></li><li><a href="/wiki/Category:Zionist_political_parties_in_Israel" title="Category:Zionist political parties in Israel">Zionist political parties in Israel</a></li></ul></div><div id="mw-hidden-catlinks" class="mw-hidden-catlinks mw-hidden-cats-hidden">Hidden categories: <ul><li><a href="/wiki/Category:Articles_with_a_promotional_tone_from_October_2016" title="Category:Articles with a promotional tone from October 2016">Articles with a promotional tone from October 2016</a></li><li><a href="/wiki/Category:All_articles_with_a_promotional_tone" title="Category:All articles with a promotional tone">All articles with a promotional tone</a></li><li><a href="/wiki/Category:Pages_using_deprecated_image_syntax" title="Category:Pages using deprecated image syntax">Pages using deprecated image syntax</a></li><li><a href="/wiki/Category:All_articles_with_unsourced_statements" title="Category:All articles with unsourced statements">All articles with unsourced statements</a></li><li><a href="/wiki/Category:Articles_with_unsourced_statements_from_February_2017" title="Category:Articles with unsourced statements from February 2017">Articles with unsourced statements from February 2017</a></li></ul></div></div>				<div class="visualClear"></div>
# 							</div>
# 		</div>
# 		<div id="mw-navigation">
# 			<h2>Navigation menu</h2>
#
# 			<div id="mw-head">
# 									<div id="p-personal" role="navigation" class="" aria-labelledby="p-personal-label">
# 						<h3 id="p-personal-label">Personal tools</h3>
# 						<ul>
# 							<li id="pt-anonuserpage">Not logged in</li><li id="pt-anontalk"><a href="/wiki/Special:MyTalk" title="Discussion about edits from this IP address [n]" accesskey="n">Talk</a></li><li id="pt-anoncontribs"><a href="/wiki/Special:MyContributions" title="A list of edits made from this IP address [y]" accesskey="y">Contributions</a></li><li id="pt-createaccount"><a href="/w/index.php?title=Special:CreateAccount&amp;returnto=Zehut" title="You are encouraged to create an account and log in; however, it is not mandatory">Create account</a></li><li id="pt-login"><a href="/w/index.php?title=Special:UserLogin&amp;returnto=Zehut" title="You're encouraged to log in; however, it's not mandatory. [o]" accesskey="o">Log in</a></li>						</ul>
# 					</div>
# 									<div id="left-navigation">
# 										<div id="p-namespaces" role="navigation" class="vectorTabs" aria-labelledby="p-namespaces-label">
# 						<h3 id="p-namespaces-label">Namespaces</h3>
# 						<ul>
# 															<li  id="ca-nstab-main" class="selected"><span><a href="/wiki/Zehut"  title="View the content page [c]" accesskey="c">Article</a></span></li>
# 															<li  id="ca-talk"><span><a href="/wiki/Talk:Zehut"  title="Discussion about the content page [t]" accesskey="t" rel="discussion">Talk</a></span></li>
# 													</ul>
# 					</div>
# 										<div id="p-variants" role="navigation" class="vectorMenu emptyPortlet" aria-labelledby="p-variants-label">
# 												<h3 id="p-variants-label">
# 							<span>Variants</span><a href="#"></a>
# 						</h3>
#
# 						<div class="menu">
# 							<ul>
# 															</ul>
# 						</div>
# 					</div>
# 									</div>
# 				<div id="right-navigation">
# 										<div id="p-views" role="navigation" class="vectorTabs" aria-labelledby="p-views-label">
# 						<h3 id="p-views-label">Views</h3>
# 						<ul>
# 															<li id="ca-view" class="selected"><span><a href="/wiki/Zehut" >Read</a></span></li>
# 															<li id="ca-edit"><span><a href="/w/index.php?title=Zehut&amp;action=edit"  title="Edit this page [e]" accesskey="e">Edit</a></span></li>
# 															<li id="ca-history" class="collapsible"><span><a href="/w/index.php?title=Zehut&amp;action=history"  title="Past revisions of this page [h]" accesskey="h">View history</a></span></li>
# 													</ul>
# 					</div>
# 										<div id="p-cactions" role="navigation" class="vectorMenu emptyPortlet" aria-labelledby="p-cactions-label">
# 						<h3 id="p-cactions-label"><span>More</span><a href="#"></a></h3>
#
# 						<div class="menu">
# 							<ul>
# 															</ul>
# 						</div>
# 					</div>
# 										<div id="p-search" role="search">
# 						<h3>
# 							<label for="searchInput">Search</label>
# 						</h3>
#
# 						<form action="/w/index.php" id="searchform">
# 							<div id="simpleSearch">
# 							<input type="search" name="search" placeholder="Search Wikipedia" title="Search Wikipedia [f]" accesskey="f" id="searchInput"/><input type="hidden" value="Special:Search" name="title"/><input type="submit" name="fulltext" value="Search" title="Search Wikipedia for this text" id="mw-searchButton" class="searchButton mw-fallbackSearchButton"/><input type="submit" name="go" value="Go" title="Go to a page with this exact name if it exists" id="searchButton" class="searchButton"/>							</div>
# 						</form>
# 					</div>
# 									</div>
# 			</div>
# 			<div id="mw-panel">
# 				<div id="p-logo" role="banner"><a class="mw-wiki-logo" href="/wiki/Main_Page"  title="Visit the main page"></a></div>
# 						<div class="portal" role="navigation" id='p-navigation' aria-labelledby='p-navigation-label'>
# 			<h3 id='p-navigation-label'>Navigation</h3>
#
# 			<div class="body">
# 									<ul>
# 						<li id="n-mainpage-description"><a href="/wiki/Main_Page" title="Visit the main page [z]" accesskey="z">Main page</a></li><li id="n-contents"><a href="/wiki/Portal:Contents" title="Guides to browsing Wikipedia">Contents</a></li><li id="n-featuredcontent"><a href="/wiki/Portal:Featured_content" title="Featured content – the best of Wikipedia">Featured content</a></li><li id="n-currentevents"><a href="/wiki/Portal:Current_events" title="Find background information on current events">Current events</a></li><li id="n-randompage"><a href="/wiki/Special:Random" title="Load a random article [x]" accesskey="x">Random article</a></li><li id="n-sitesupport"><a href="https://donate.wikimedia.org/wiki/Special:FundraiserRedirector?utm_source=donate&amp;utm_medium=sidebar&amp;utm_campaign=C13_en.wikipedia.org&amp;uselang=en" title="Support us">Donate to Wikipedia</a></li><li id="n-shoplink"><a href="//shop.wikimedia.org" title="Visit the Wikipedia store">Wikipedia store</a></li>					</ul>
# 							</div>
# 		</div>
# 			<div class="portal" role="navigation" id='p-interaction' aria-labelledby='p-interaction-label'>
# 			<h3 id='p-interaction-label'>Interaction</h3>
#
# 			<div class="body">
# 									<ul>
# 						<li id="n-help"><a href="/wiki/Help:Contents" title="Guidance on how to use and edit Wikipedia">Help</a></li><li id="n-aboutsite"><a href="/wiki/Wikipedia:About" title="Find out about Wikipedia">About Wikipedia</a></li><li id="n-portal"><a href="/wiki/Wikipedia:Community_portal" title="About the project, what you can do, where to find things">Community portal</a></li><li id="n-recentchanges"><a href="/wiki/Special:RecentChanges" title="A list of recent changes in the wiki [r]" accesskey="r">Recent changes</a></li><li id="n-contactpage"><a href="//en.wikipedia.org/wiki/Wikipedia:Contact_us" title="How to contact Wikipedia">Contact page</a></li>					</ul>
# 							</div>
# 		</div>
# 			<div class="portal" role="navigation" id='p-tb' aria-labelledby='p-tb-label'>
# 			<h3 id='p-tb-label'>Tools</h3>
#
# 			<div class="body">
# 									<ul>
# 						<li id="t-whatlinkshere"><a href="/wiki/Special:WhatLinksHere/Zehut" title="List of all English Wikipedia pages containing links to this page [j]" accesskey="j">What links here</a></li><li id="t-recentchangeslinked"><a href="/wiki/Special:RecentChangesLinked/Zehut" rel="nofollow" title="Recent changes in pages linked from this page [k]" accesskey="k">Related changes</a></li><li id="t-upload"><a href="/wiki/Wikipedia:File_Upload_Wizard" title="Upload files [u]" accesskey="u">Upload file</a></li><li id="t-specialpages"><a href="/wiki/Special:SpecialPages" title="A list of all special pages [q]" accesskey="q">Special pages</a></li><li id="t-permalink"><a href="/w/index.php?title=Zehut&amp;oldid=765862038" title="Permanent link to this revision of the page">Permanent link</a></li><li id="t-info"><a href="/w/index.php?title=Zehut&amp;action=info" title="More information about this page">Page information</a></li><li id="t-wikibase"><a href="https://www.wikidata.org/wiki/Q23304767" title="Link to connected data repository item [g]" accesskey="g">Wikidata item</a></li><li id="t-cite"><a href="/w/index.php?title=Special:CiteThisPage&amp;page=Zehut&amp;id=765862038" title="Information on how to cite this page">Cite this page</a></li>					</ul>
# 							</div>
# 		</div>
# 			<div class="portal" role="navigation" id='p-coll-print_export' aria-labelledby='p-coll-print_export-label'>
# 			<h3 id='p-coll-print_export-label'>Print/export</h3>
#
# 			<div class="body">
# 									<ul>
# 						<li id="coll-create_a_book"><a href="/w/index.php?title=Special:Book&amp;bookcmd=book_creator&amp;referer=Zehut">Create a book</a></li><li id="coll-download-as-rdf2latex"><a href="/w/index.php?title=Special:Book&amp;bookcmd=render_article&amp;arttitle=Zehut&amp;returnto=Zehut&amp;oldid=765862038&amp;writer=rdf2latex">Download as PDF</a></li><li id="t-print"><a href="/w/index.php?title=Zehut&amp;printable=yes" title="Printable version of this page [p]" accesskey="p">Printable version</a></li>					</ul>
# 							</div>
# 		</div>
# 			<div class="portal" role="navigation" id='p-lang' aria-labelledby='p-lang-label'>
# 			<h3 id='p-lang-label'>Languages</h3>
#
# 			<div class="body">
# 									<ul>
# 						<li class="interlanguage-link interwiki-he"><a href="https://he.wikipedia.org/wiki/%D7%96%D7%94%D7%95%D7%AA_-_%D7%AA%D7%A0%D7%95%D7%A2%D7%94_%D7%99%D7%A9%D7%A8%D7%90%D7%9C%D7%99%D7%AA_%D7%99%D7%94%D7%95%D7%93%D7%99%D7%AA" title="זהות - תנועה ישראלית יהודית – Hebrew" lang="he" hreflang="he" class="interlanguage-link-target">עברית</a></li>					</ul>
# 				<div class='after-portlet after-portlet-lang'><span class="wb-langlinks-edit wb-langlinks-link"><a href="https://www.wikidata.org/wiki/Q23304767#sitelinks-wikipedia" title="Edit interlanguage links" class="wbc-editpage">Edit links</a></span></div>			</div>
# 		</div>
# 				</div>
# 		</div>
# 		<div id="footer" role="contentinfo">
# 							<ul id="footer-info">
# 											<li id="footer-info-lastmod"> This page was last modified on 16 February 2017, at 21:17.</li>
# 											<li id="footer-info-copyright">Text is available under the <a rel="license" href="//en.wikipedia.org/wiki/Wikipedia:Text_of_Creative_Commons_Attribution-ShareAlike_3.0_Unported_License">Creative Commons Attribution-ShareAlike License</a><a rel="license" href="//creativecommons.org/licenses/by-sa/3.0/" style="display:none;"></a>;
# additional terms may apply.  By using this site, you agree to the <a href="//wikimediafoundation.org/wiki/Terms_of_Use">Terms of Use</a> and <a href="//wikimediafoundation.org/wiki/Privacy_policy">Privacy Policy</a>. Wikipedia® is a registered trademark of the <a href="//www.wikimediafoundation.org/">Wikimedia Foundation, Inc.</a>, a non-profit organization.</li>
# 									</ul>
# 							<ul id="footer-places">
# 											<li id="footer-places-privacy"><a href="https://wikimediafoundation.org/wiki/Privacy_policy" class="extiw" title="wmf:Privacy policy">Privacy policy</a></li>
# 											<li id="footer-places-about"><a href="/wiki/Wikipedia:About" title="Wikipedia:About">About Wikipedia</a></li>
# 											<li id="footer-places-disclaimer"><a href="/wiki/Wikipedia:General_disclaimer" title="Wikipedia:General disclaimer">Disclaimers</a></li>
# 											<li id="footer-places-contact"><a href="//en.wikipedia.org/wiki/Wikipedia:Contact_us">Contact Wikipedia</a></li>
# 											<li id="footer-places-developers"><a href="https://www.mediawiki.org/wiki/Special:MyLanguage/How_to_contribute">Developers</a></li>
# 											<li id="footer-places-cookiestatement"><a href="https://wikimediafoundation.org/wiki/Cookie_statement">Cookie statement</a></li>
# 											<li id="footer-places-mobileview"><a href="//en.m.wikipedia.org/w/index.php?title=Zehut&amp;mobileaction=toggle_view_mobile" class="noprint stopMobileRedirectToggle">Mobile view</a></li>
# 									</ul>
# 										<ul id="footer-icons" class="noprint">
# 											<li id="footer-copyrightico">
# 							<a href="https://wikimediafoundation.org/"><img src="/static/images/wikimedia-button.png" srcset="/static/images/wikimedia-button-1.5x.png 1.5x, /static/images/wikimedia-button-2x.png 2x" width="88" height="31" alt="Wikimedia Foundation"/></a>						</li>
# 											<li id="footer-poweredbyico">
# 							<a href="//www.mediawiki.org/"><img src="/static/images/poweredby_mediawiki_88x31.png" alt="Powered by MediaWiki" srcset="/static/images/poweredby_mediawiki_132x47.png 1.5x, /static/images/poweredby_mediawiki_176x62.png 2x" width="88" height="31"/></a>						</li>
# 									</ul>
# 						<div style="clear:both"></div>
# 		</div>
# 		<script>(window.RLQ=window.RLQ||[]).push(function(){mw.config.set({"wgPageParseReport":{"limitreport":{"cputime":"0.212","walltime":"0.271","ppvisitednodes":{"value":1806,"limit":1000000},"ppgeneratednodes":{"value":0,"limit":1500000},"postexpandincludesize":{"value":35657,"limit":2097152},"templateargumentsize":{"value":2804,"limit":2097152},"expansiondepth":{"value":21,"limit":40},"expensivefunctioncount":{"value":5,"limit":500},"entityaccesscount":{"value":0,"limit":400},"timingprofile":["100.00%  239.293      1 -total"," 45.05%  107.811      1 Template:Infobox_political_party"," 38.10%   91.176      1 Template:Infobox"," 32.95%   78.838      1 Template:Reflist"," 24.72%   59.158     11 Template:Cite_web"," 19.58%   46.863      1 Template:Advert"," 14.60%   34.928      2 Template:Citation_needed"," 13.27%   31.763      2 Template:Fix"," 12.11%   28.985      1 Template:Ambox","  7.81%   18.682      2 Template:Delink"]},"scribunto":{"limitreport-timeusage":{"value":"0.101","limit":"10.000"},"limitreport-memusage":{"value":4952875,"limit":52428800}},"cachereport":{"origin":"mw1220","timestamp":"20170221103941","ttl":2592000,"transientcontent":false}}});});</script><script>(window.RLQ=window.RLQ||[]).push(function(){mw.config.set({"wgBackendResponseTime":57,"wgHostname":"mw1216"});});</script>
# 	</body>
# </html>

# %% [markdown]
# It appears that the main content is nested inside the div tag with the id content.

# %% [markdown]
# # Reading in the Data

# %%
import concurrent.futures
import time

pool = concurrent.futures.ThreadPoolExecutor(max_workers = 5)

def read_data(filename):
    with open(filename, encoding="utf8") as f:
        data = f.read()
    return data

# Read all of the files into list called content
file_list = ["wiki/{}".format(f) for f in os.listdir('wiki')]
content = list(pool.map(read_data, file_list))

# Create a list called articles that contains the article names
articles = [f.replace('wiki/', '').replace('.html', '') for f in file_list]

articles[:10]
# Out:
# ['Cristian_Berdeja',
#  'Bob_Bass',
#  'Louis_Vivet',
#  '104th_Logistic_Support_Brigade_(United_Kingdom)',
#  'Zehut',
#  'Christine_Gardner',
#  'I%27m_Walking_Behind_You',
#  'Bill_Widenhouse',
#  'Friendship,_Wake_County,_North_Carolina',
#  'Harry_Lynde_Bradley']

# %%
# Test max_workers

time_run = {}

for i in range(8):
    test_pool = concurrent.futures.ThreadPoolExecutor(max_workers = (i+1))
    start = time.time()
    file_list_test = ["wiki/{}".format(f) for f in os.listdir('wiki')]
    content_test = list(pool.map(read_data, file_list))
    time_run[i+1] = time.time() - start
    
time_run
# Out:
# {1: 1.096341848373413,
#  2: 1.0523681640625,
#  3: 1.034379005432129,
#  4: 1.0583646297454834,
#  5: 1.1493098735809326,
#  6: 1.071357011795044,
#  7: 1.2092738151550293,
#  8: 1.211272954940796}

# %% [markdown]
# time_run showed little improvement with numbers of thread, likely result of offset from creating thread.

# %% [markdown]
# # Remove the extraneous markup

# %%
from bs4 import BeautifulSoup
import parse # from parse.py

#def parse_html(html):
    #soup = BeautifulSoup(open(html), 'html.parser')
    #return str(soup.find_all("div", id="content")[0])
# function was saved in parse.py to work around Windows multiprocessing bug in Jupyter

time_parse = {}
if __name__ == '__main__':
    for i in range(6):
        start = time.time()
        pool = concurrent.futures.ProcessPoolExecutor(max_workers = (i+1))
        parsed = list(pool.map(parse.parse_html, content))
        time_parse[i+1] = time.time() - start  

if __name__ == '__main__':
    pool = concurrent.futures.ProcessPoolExecutor(max_workers = (i+1))
    parsed = list(pool.map(parse.parse_html, content))
    
time_parse
# Out:
# {1: 50.452088356018066,
#  2: 25.340067148208618,
#  3: 17.585516452789307,
#  4: 15.815162420272827,
#  5: 15.450891971588135,
#  6: 14.01800012588501}

# %% [markdown]
# This operation is quite slow and CPU-intensive. It looks like using as many processes are there are available processors speeds things up. However, performance peaks around 5 max_workers. More processes would have significantly impact other computer operations.

# %% [markdown]
# # Finding Common Tags

# %%
from bs4 import BeautifulSoup
import tagCount

if __name__ == '__main__':
    pool_tag = concurrent.futures.ProcessPoolExecutor(max_workers = 4)
    tag_list = list(pool_tag.map(tagCount.tag_count, parsed))

tag_dict = {}

for tag in tag_list:
    for k, v in tag.items():
        if k not in tag_dict:
            tag_dict[k] = 0
        tag_dict[k] += v
        
sort_tag = sorted(tag_dict.items(), key=lambda kv: kv[1], reverse=True)

tag = dict(sort_tag)

tag
# Out:
# {'a': 161065,
#  'li': 85779,
#  'span': 67350,
#  'td': 57673,
#  'div': 28581,
#  'tr': 27300,
#  'i': 18246,
#  'th': 14472,
#  'b': 14455,
#  'sup': 11157,
#  'ul': 10972,
#  'p': 7998,
#  'img': 6701,
#  'br': 4986,
#  'h2': 4045,
#  'table': 4010,
#  'abbr': 3665,
#  'cite': 3563,
#  'small': 3272,
#  'dd': 1376,
#  'h1': 999,
#  'noscript': 999,
#  'ol': 858,
#  'h3': 777,
#  'strong': 599,
#  'dl': 457,
#  'dt': 334,
#  'caption': 200,
#  'sub': 151,
#  'h4': 117,
#  'code': 108,
#  'wbr': 85,
#  'q': 76,
#  'big': 75,
#  'center': 64,
#  'blockquote': 58,
#  'hr': 51,
#  'u': 51,
#  'font': 40,
#  'area': 39,
#  'rp': 32,
#  'ruby': 16,
#  'rb': 16,
#  'rt': 16,
#  's': 10,
#  'bdi': 4,
#  'h5': 4,
#  'audio': 2,
#  'source': 2,
#  'del': 2,
#  'map': 2,
#  'math': 2,
#  'semantics': 2,
#  'mrow': 2,
#  'mstyle': 2,
#  'mo': 2,
#  'annotation': 2,
#  'samp': 2,
#  'pre': 1,
#  'h6': 1}

# %% [markdown]
# Based on our findings, it looks like there are quite a few td, a, li, and span tags. This indicates that articles tend to have lots of links, along with lists and tables. Links are the most numerous tag, which indicates how interconnected articles on Wikipedia are.

# %% [markdown]
# # Find common words

# %%
from bs4 import BeautifulSoup
import wordCount

start = time.time()
if __name__ == '__main__':
    pool_word = concurrent.futures.ProcessPoolExecutor(max_workers = 4)
    word_list = list(pool_word.map(wordCount.word_count, parsed))

word_dict = {}

for word in word_list:
    for each in word:
        if each[0] not in word_dict:
            word_dict[each[0]] = 0
        word_dict[each[0]] += each[1]

print(time.time() - start)
sort_word = sorted(word_dict.items(), key=lambda kv: kv[1], reverse=True)

words = dict(sort_word)

words
# Out:
# 7.506750822067261
# {'retrieved': 1733,
#  'wikipedia': 1310,
#  'united': 781,
#  'production': 686,
#  'university': 635,
#  'articles': 594,
#  'italian': 594,
#  'italy': 536,
#  'county': 533,
#  'district': 485,
#  'school': 483,
#  'species': 420,
#  'bellator': 367,
#  'national': 358,
#  'states': 351,
#  'article': 336,
#  'station': 335,
#  'party': 326,
#  'league': 317,
#  'french': 298,
#  'spanish': 296,
#  'texas': 291,
#  'women': 289,
#  'church': 288,
#  'august': 287,
#  'state': 285,
#  'march': 281,
#  'campus': 280,
#  'world': 278,
#  'german': 278,
#  'october': 278,
#  'south': 275,
#  'yards': 275,
#  'season': 269,
#  'football': 259,
#  'november': 259,
#  'family': 252,
#  'american': 248,
#  'album': 247,
#  'september': 245,
#  'music': 244,
#  'which': 243,
#  'february': 242,
#  'series': 236,
#  'december': 225,
#  'north': 222,
#  'original': 221,
#  'vikings': 207,
#  'avengers': 203,
#  'their': 202,
#  'company': 202,
#  'building': 198,
#  'academy': 198,
#  'image': 197,
#  'archived': 196,
#  'saint': 191,
#  'alabama': 190,
#  'college': 187,
#  'january': 184,
#  'youtube': 183,
#  'population': 181,
#  'television': 178,
#  'india': 174,
#  'white': 172,
#  'historic': 170,
#  'rangers': 167,
#  'april': 166,
#  'career': 163,
#  'genus': 161,
#  'bangor': 158,
#  'director': 156,
#  'california': 156,
#  'marine': 152,
#  'center': 151,
#  'field': 151,
#  'railway': 151,
#  'social': 150,
#  'drive': 150,
#  'island': 149,
#  'pound': 148,
#  'plant': 147,
#  'australian': 146,
#  'river': 146,
#  'germany': 146,
#  'plays': 145,
#  'black': 144,
#  'minnesota': 141,
#  'register': 138,
#  'times': 137,
#  'tennessee': 136,
#  'division': 133,
#  'museum': 132,
#  'village': 132,
#  'lille': 132,
#  'stadium': 131,
#  'released': 130,
#  'street': 130,
#  'bishop': 130,
#  'group': 129,
#  'international': 124,
#  'categories': 123,
#  'oblast': 123,
#  'british': 120,
#  'antibiotics': 119,
#  'first': 118,
#  'battle': 118,
#  'after': 118,
#  'danes': 118,
#  'military': 118,
#  'census': 117,
#  'water': 116,
#  'there': 116,
#  'other': 115,
#  'hockey': 114,
#  'round': 114,
#  'william': 113,
#  'antibiotic': 113,
#  'founded': 110,
#  'coordinates': 109,
#  'canada': 109,
#  'green': 108,
#  'wellington': 108,
#  'house': 107,
#  'dragnet': 107,
#  'sources': 106,
#  'format': 106,
#  'general': 106,
#  'township': 105,
#  'chart': 104,
#  'union': 103,
#  'championship': 102,
#  'quarter': 102,
#  'coups': 102,
#  'albums': 101,
#  'manhattan': 100,
#  'central': 99,
#  'order': 99,
#  'chemical': 99,
#  'video': 98,
#  'records': 96,
#  'history': 96,
#  'places': 96,
#  'airport': 95,
#  'science': 94,
#  'service': 93,
#  'japan': 93,
#  'labour': 92,
#  'jones': 91,
#  'liberal': 91,
#  'roofs': 91,
#  'pieces': 91,
#  'region': 90,
#  'track': 89,
#  'administrative': 89,
#  'language': 88,
#  'students': 88,
#  'australia': 87,
#  'engineering': 87,
#  'giants': 87,
#  'williams': 86,
#  'radio': 86,
#  'harry': 84,
#  'province': 84,
#  'avenue': 84,
#  'names': 84,
#  'virus': 84,
#  'islands': 82,
#  'election': 82,
#  'angeles': 82,
#  'sheehan': 82,
#  'england': 81,
#  'villa': 81,
#  'country': 80,
#  'области': 80,
#  'mazzucato': 80,
#  'belvedere': 80,
#  'subgenius': 80,
#  'mattel': 80,
#  'member': 79,
#  'james': 79,
#  'toronto': 79,
#  'russian': 79,
#  'chicago': 79,
#  'municipal': 79,
#  'stations': 78,
#  'force': 78,
#  'producer': 77,
#  'comics': 77,
#  'tropical': 77,
#  'basketball': 76,
#  'tolombeh': 76,
#  'awards': 76,
#  'temple': 76,
#  'pushkar': 76,
#  'carolina': 75,
#  'chinese': 75,
#  'rugby': 75,
#  'baseball': 75,
#  'republic': 75,
#  'sofla': 75,
#  'london': 75,
#  'system': 75,
#  'ireland': 74,
#  'business': 74,
#  'auckland': 73,
#  'brooklyn': 73,
#  'actress': 73,
#  'children': 72,
#  'wisconsin': 72,
#  'knoxville': 72,
#  'innovation': 72,
#  'hepatitis': 72,
#  'catalan': 72,
#  'information': 71,
#  'political': 70,
#  'virginia': 70,
#  'salle': 70,
#  'oregon': 69,
#  'elections': 69,
#  'kansas': 69,
#  'rockefeller': 69,
#  'birds': 69,
#  'external': 68,
#  'president': 68,
#  'event': 68,
#  'billboard': 68,
#  'mickey': 68,
#  'plants': 68,
#  'bandholtz': 68,
#  'zealand': 67,
#  'episodes': 67,
#  'space': 67,
#  'george': 67,
#  'review': 67,
#  'protein': 67,
#  'source': 67,
#  'identifierswikipedia': 66,
#  'position': 66,
#  'animal': 66,
#  'école': 66,
#  'amazon': 66,
#  'championships': 65,
#  'development': 65,
#  'medal': 65,
#  'arena': 65,
#  'stone': 65,
#  'westchester': 65,
#  'foundation': 64,
#  'society': 64,
#  'about': 64,
#  'twist': 64,
#  'council': 64,
#  'danish': 64,
#  'uganda': 64,
#  'mount': 63,
#  'smith': 63,
#  'hamilton': 63,
#  'democrat': 63,
#  'livestock': 63,
#  'husband': 63,
#  'ridge': 63,
#  'hackensaw': 63,
#  'songs': 62,
#  'croatia': 62,
#  'oktyabrsky': 62,
#  'drama': 62,
#  'legge': 62,
#  'conference': 61,
#  'images': 61,
#  'painter': 61,
#  'allen': 60,
#  'century': 60,
#  'court': 60,
#  'second': 60,
#  'malta': 60,
#  'colony': 60,
#  'sequence': 60,
#  'limited': 60,
#  'resistance': 60,
#  'maurice': 60,
#  'morning': 60,
#  'years': 59,
#  'design': 59,
#  'casino': 59,
#  'construction': 59,
#  'racing': 59,
#  'marvel': 59,
#  'artist': 59,
#  'class': 58,
#  'morgana': 58,
#  'poland': 58,
#  'sport': 58,
#  'claire': 58,
#  'bratz': 58,
#  'cyclone': 58,
#  'junior': 57,
#  'david': 57,
#  'maine': 57,
#  'cricket': 57,
#  'murray': 57,
#  'agonists': 57,
#  'washington': 57,
#  'videos': 57,
#  'research': 56,
#  'parliament': 56,
#  'metallica': 56,
#  'festival': 56,
#  'minister': 56,
#  'catholic': 56,
#  'territorial': 56,
#  'robert': 56,
#  'pasha': 56,
#  'writer': 56,
#  'animals': 56,
#  'acorah': 56,
#  'morales': 56,
#  'bolívar': 56,
#  'mosque': 56,
#  'scottish': 55,
#  'sudan': 55,
#  'airlines': 55,
#  'played': 55,
#  'education': 55,
#  'blues': 55,
#  'thomas': 55,
#  'would': 55,
#  'petrolero': 55,
#  'tubular': 55,
#  'additional': 54,
#  'journal': 54,
#  'people': 54,
#  'swing': 54,
#  'corps': 53,
#  'silver': 53,
#  'single': 53,
#  'score': 53,
#  'great': 53,
#  'kingdom': 53,
#  'amborella': 53,
#  'attack': 53,
#  'bells': 53,
#  'wallace': 53,
#  'glory': 53,
#  'aikido': 52,
#  'coffee': 52,
#  'columbia': 52,
#  'russell': 52,
#  'japanese': 52,
#  'dodgers': 52,
#  'player': 52,
#  'shire': 52,
#  'intel': 51,
#  'sudanese': 51,
#  'chair': 51,
#  'stage': 51,
#  'jules': 50,
#  'verne': 50,
#  'sports': 50,
#  'административно': 50,
#  'france': 50,
#  'community': 50,
#  'hospital': 50,
#  'laboratoire': 50,
#  'cybernetics': 50,
#  'corporations': 50,
#  'parties': 49,
#  'management': 49,
#  'rural': 49,
#  'queensland': 49,
#  'bridge': 49,
#  'report': 49,
#  'queen': 49,
#  'right': 49,
#  'kampala': 49,
#  'franja': 49,
#  'valley': 48,
#  'assembly': 48,
#  'devitt': 48,
#  'korean': 48,
#  'hawke': 48,
#  'present': 48,
#  'government': 48,
#  'закон': 48,
#  'performance': 48,
#  'formula': 48,
#  'foster': 48,
#  'nelson': 48,
#  'global': 48,
#  'chickens': 48,
#  'encyclopedia': 47,
#  'schools': 47,
#  'english': 47,
#  'weise': 47,
#  'creek': 47,
#  'nations': 47,
#  'bradford': 47,
#  'security': 47,
#  'oklahoma': 46,
#  'curling': 46,
#  'instrumental': 46,
#  'municipality': 46,
#  'references': 46,
#  'wanderers': 46,
#  'опубликован': 46,
#  'birmingham': 46,
#  'trust': 46,
#  'membrane': 46,
#  'geographic': 46,
#  'ellington': 46,
#  'tasman': 45,
#  'aircraft': 45,
#  'results': 45,
#  'number': 44,
#  'cheshmeh': 44,
#  'became': 44,
#  'death': 44,
#  'biorock': 44,
#  'welfare': 44,
#  'jourdan': 44,
#  'revolution': 44,
#  'palace': 44,
#  'oliver': 44,
#  'christos': 44,
#  'gamede': 44,
#  'strongest': 44,
#  'singles': 43,
#  'point': 43,
#  'title': 43,
#  'pakistan': 43,
#  'nationale': 43,
#  'darreh': 43,
#  'colliery': 43,
#  'tamil': 43,
#  'posthumous': 43,
#  'antagonists': 43,
#  'chicken': 43,
#  'derek': 43,
#  'apertura': 43,
#  'bogan': 43,
#  'alberta': 42,
#  'actor': 42,
#  'metres': 42,
#  'legislative': 42,
#  'luzon': 42,
#  'common': 42,
#  'survey': 42,
#  'cobble': 42,
#  'israel': 41,
#  'mountain': 41,
#  'oldfield': 41,
#  'votes': 41,
#  'drugs': 41,
#  'kenny': 41,
#  'carlos': 41,
#  'rosemann': 41,
#  'karnataka': 41,
#  'governor': 41,
#  'oriente': 41,
#  'label': 40,
#  'earth': 40,
#  'goals': 40,
#  'garden': 40,
#  'winter': 40,
#  'western': 40,
#  'soviet': 40,
#  'treaty': 40,
#  'peptide': 40,
#  'remove': 40,
#  'worldwide': 40,
#  'warbler': 40,
#  'andrews': 40,
#  'mines': 40,
#  'communist': 40,
#  'leeds': 40,
#  'elgin': 40,
#  'myrtle': 40,
#  'coach': 39,
#  'royal': 39,
#  'spain': 39,
#  'structure': 39,
#  'romania': 39,
#  'nematodes': 39,
#  'roofing': 39,
#  'conferences': 39,
#  'aragon': 39,
#  'geological': 39,
#  'record': 38,
#  'links': 38,
#  'yoshinkan': 38,
#  'cannabis': 38,
#  'latin': 38,
#  'grand': 38,
#  'coral': 38,
#  'athletic': 38,
#  'sacksioni': 38,
#  'zeiraphera': 38,
#  'learning': 38,
#  'caramagna': 38,
#  'cusack': 38,
#  'examiner': 38,
#  'epichorista': 38,
#  'indian': 37,
#  'classic': 37,
#  'conformations': 37,
#  'anthony': 37,
#  'urban': 37,
#  'greek': 37,
#  'majority': 37,
#  'tarsila': 37,
#  'watch': 37,
#  'crowned': 37,
#  'marne': 37,
#  'socket': 37,
#  'clausura': 37,
#  'total': 36,
#  'against': 36,
#  'currency': 36,
#  'location': 36,
#  'coast': 36,
#  'conformation': 36,
#  'empty': 36,
#  'cocker': 36,
#  'human': 36,
#  'keller': 36,
#  'hungary': 36,
#  'institute': 36,
#  'plains': 36,
#  'morris': 36,
#  'maitland': 36,
#  'comedy': 36,
#  'rights': 36,
#  'politics': 36,
#  'candidate': 36,
#  'polish': 36,
#  'asphalt': 36,
#  'swindon': 36,
#  'yarkand': 36,
#  'clarinet': 36,
#  'possible': 36,
#  'aragón': 36,
#  'checa': 36,
#  'learn': 35,
#  'short': 35,
#  'effect': 35,
#  'members': 35,
#  'magazine': 35,
#  'southern': 35,
#  'section': 35,
#  'discretionary': 35,
#  'illinois': 35,
#  'resistant': 35,
#  'novel': 35,
#  'greens': 35,
#  'anderson': 35,
#  'govindarajan': 35,
#  'putnam': 35,
#  'damascus': 35,
#  'program': 34,
#  'athletics': 34,
#  'message': 34,
#  'cyclohexane': 34,
#  'hunter': 34,
#  'pirates': 34,
#  'project': 34,
#  'dakota': 34,
#  'media': 34,
#  'switzerland': 34,
#  'protocols': 34,
#  'theater': 34,
#  'georgia': 34,
#  'points': 34,
#  'supermoon': 34,
#  'speer': 34,
#  'huesca': 34,
#  'larsen': 34,
#  'public': 33,
#  'executive': 33,
#  'centre': 33,
#  'magnetic': 33,
#  'keaton': 33,
#  'lakes': 33,
#  'featuring': 33,
#  'norway': 33,
#  'cities': 33,
#  'newton': 33,
#  'never': 33,
#  'liberty': 33,
#  'newspaper': 33,
#  'birth': 32,
#  'natural': 32,
#  'board': 32,
#  'strategic': 32,
#  'houses': 32,
#  'square': 32,
#  'imperial': 32,
#  'published': 32,
#  'melbourne': 32,
#  'seattle': 32,
#  'chandor': 32,
#  'meyrick': 32,
#  'expeditionary': 32,
#  'alaska': 32,
#  'cathedral': 32,
#  'based': 32,
#  'barrens': 32,
#  'magee': 32,
#  'wilstermann': 32,
#  'described': 31,
#  'young': 31,
#  'dutch': 31,
#  'dinar': 31,
#  'kentucky': 31,
#  'goreau': 31,
#  'foreign': 31,
#  'brown': 31,
#  'maubeuge': 31,
#  'wales': 31,
#  'ushiba': 31,
#  'molecular': 31,
#  'chester': 31,
#  'ladies': 31,
#  'sprue': 31,
#  'jorge': 31,
#  'fleur': 31,
#  'layer': 30,
#  'movie': 30,
#  'insurance': 30,
#  'mahalleh': 30,
#  'paulo': 30,
#  'bombardment': 30,
#  'sexism': 30,
#  'richard': 30,
#  'battalions': 30,
#  'phipps': 30,
#  'summer': 30,
#  'inning': 30,
#  'arkansas': 30,
#  'built': 30,
#  'major': 30,
#  'content': 30,
#  'swedish': 29,
#  'hardy': 29,
#  'sabbath': 29,
#  'served': 29,
#  'services': 29,
#  'olympic': 29,
#  'night': 29,
#  'brazilian': 29,
#  'nickel': 29,
#  'directed': 29,
#  'swiss': 29,
#  'storm': 29,
#  'student': 29,
#  'tuscaloosa': 29,
#  'metro': 29,
#  'genome': 29,
#  'linux': 29,
#  'institut': 29,
#  'hackney': 29,
#  'episode': 29,
#  'khadr': 29,
#  'beasley': 29,
#  'groves': 29,
#  'harvard': 29,
#  'braille': 29,
#  'regiment': 28,
#  'komaroff': 28,
#  'trophy': 28,
#  'chief': 28,
#  'coins': 28,
#  'related': 28,
#  'massachusetts': 28,
#  'citations': 28,
#  'unranked': 28,
#  'theatre': 28,
#  'version': 28,
#  'roman': 28,
#  'canadian': 28,
#  'wattignies': 28,
#  'johnson': 28,
#  'minor': 28,
#  'brooke': 28,
#  'northern': 28,
#  'flowering': 28,
#  'autism': 28,
#  'symeon': 28,
#  'moore': 28,
#  'jeremy': 28,
#  'writing': 28,
#  'cryptographic': 28,
#  'clinton': 28,
#  'kilkenny': 28,
#  'brooks': 28,
#  'slade': 28,
#  'clarkes': 28,
#  'communities': 27,
#  'observatory': 27,
#  'pounds': 27,
#  'written': 27,
#  'beyond': 27,
#  'regional': 27,
#  'aviation': 27,
#  'command': 27,
#  'airports': 27,
#  'brothers': 27,
#  'character': 27,
#  'hilbertz': 27,
#  'banovina': 27,
#  'biases': 27,
#  'psychology': 27,
#  'touchdown': 27,
#  'where': 27,
#  'coalition': 27,
#  'dupuis': 27,
#  'dresden': 27,
#  'montana': 27,
#  'department': 27,
#  'welsh': 27,
#  'johnny': 27,
#  'medical': 27,
#  'power': 27,
#  'since': 27,
#  'saladino': 27,
#  'dobbs': 27,
#  'democratic': 27,
#  'yarkant': 27,
#  'soldier': 27,
#  'pinzón': 27,
#  'dolls': 27,
#  'tribes': 27,
#  'winkle': 27,
#  'unincorporated': 26,
#  'mississippi': 26,
#  'translation': 26,
#  'dream': 26,
#  'weather': 26,
#  'conservative': 26,
#  'china': 26,
#  'later': 26,
#  'portuguese': 26,
#  'collection': 26,
#  'scotland': 26,
#  'spencer': 26,
#  'library': 26,
#  'guitar': 26,
#  'renault': 26,
#  'enzyme': 26,
#  'languages': 26,
#  'elizabeth': 26,
#  'paris': 26,
#  'moneyhunt': 26,
#  'template': 26,
#  'volleyball': 26,
#  'josiah': 26,
#  'timber': 26,
#  'urodilatin': 26,
#  'domain': 26,
#  'hagen': 26,
#  'defensive': 26,
#  'teruel': 26,
#  'little': 26,
#  'beckett': 26,
#  'seyyed': 26,
#  'statistics': 25,
#  'norwegian': 25,
#  'award': 25,
#  'search': 25,
#  'charles': 25,
#  'edmonton': 25,
#  'charts': 25,
#  'friday': 25,
#  'czech': 25,
#  'piracy': 25,
#  'operation': 25,
#  'orange': 25,
#  'historical': 25,
#  '000000002013': 25,
#  '000000002012': 25,
#  '000000002011': 25,
#  'relations': 25,
#  'opened': 25,
#  'omaha': 25,
#  'mayor': 25,
#  'impeccable': 25,
#  'denmark': 25,
#  'lungujja': 25,
#  'products': 25,
#  'cincinnati': 25,
#  'religion': 25,
#  'harrison': 25,
#  'chhatrasal': 25,
#  'corporation': 25,
#  'lincoln': 25,
#  'garfield': 25,
#  'mannafar': 25,
#  'crotty': 25,
#  'baptist': 25,
#  'pennsylvania': 25,
#  'quantum': 25,
#  'according': 25,
#  'smeaton': 25,
#  'becky': 25,
#  'senior': 24,
#  'games': 24,
#  'shahid': 24,
#  'federal': 24,
#  'super': 24,
#  'kumar': 24,
#  'between': 24,
#  'baltimore': 24,
#  'parsons': 24,
#  'durham': 24,
#  'gottfried': 24,
#  'mystery': 24,
#  'murder': 24,
#  'horace': 24,
#  'without': 24,
#  'politician': 24,
#  'items': 24,
#  'vancouver': 24,
#  'maryland': 24,
#  'purpose': 24,
#  'vatican': 24,
#  'origin': 24,
#  'digiorgio': 24,
#  'boardman': 24,
#  'double': 24,
#  'coalville': 24,
#  'insight': 24,
#  'understands': 24,
#  'chance': 24,
#  'viral': 24,
#  'framing': 24,
#  'coquille': 24,
#  'angela': 24,
#  'litera': 24,
#  'baddie': 24,
#  'vivet': 23,
#  'jewish': 23,
#  'notability': 23,
#  'patrick': 23,
#  'master': 23,
#  'biography': 23,
#  'portland': 23,
#  'mouse': 23,
#  'qatar': 23,
#  'mexican': 23,
#  'raymond': 23,
#  'fiction': 23,
#  'films': 23,
#  'reefs': 23,
#  'typhoon': 23,
#  'bulgarian': 23,
#  'lelyveld': 23,
#  'lebanon': 23,
#  'polytechnic': 23,
#  'colombia': 23,
#  'middle': 23,
#  'guantanamo': 23,
#  'dasmariñas': 23,
#  'planet': 23,
#  'olympics': 23,
#  'derived': 23,
#  'coding': 23,
#  'foliar': 23,
#  'systems': 23,
#  'clade': 23,
#  'ralston': 23,
#  'brazil': 23,
#  'saudi': 23,
#  'reilly': 23,
#  'teams': 23,
#  'muller': 23,
#  'motorsport': 23,
#  'tracks': 23,
#  'neighborhood': 23,
#  'lunar': 23,
#  'closed': 23,
#  'vegetation': 23,
#  'conte': 23,
#  'picture': 23,
#  'diamond': 23,
#  'rials': 23,
#  'tartu': 23,
#  'chhatrapati': 23,
#  'loving': 23,
#  'recorded': 22,
#  'districts': 22,
#  'promises': 22,
#  'singer': 22,
#  'henderson': 22,
#  'herald': 22,
#  'berlin': 22,
#  'rally': 22,
#  'tyrosine': 22,
#  'coliseum': 22,
#  'skating': 22,
#  'analysis': 22,
#  'angiosperms': 22,
#  'growth': 22,
#  'brahma': 22,
#  'qaleh': 22,
#  'billy': 22,
#  'martins': 22,
#  'fonseca': 22,
#  'burdine': 22,
#  'resolution': 22,
#  'lillard': 22,
#  'chiropractic': 22,
#  'maría': 22,
#  'stream': 22,
#  'maegashira': 22,
#  'philaeus': 22,
#  'redding': 22,
#  'aragonese': 22,
#  'judah': 22,
#  'rouen': 22,
#  'flashbacks': 22,
#  'factor': 22,
#  'programs': 21,
#  'prisons': 21,
#  'please': 21,
#  'areas': 21,
#  'sound': 21,
#  'story': 21,
#  'network': 21,
#  'solomona': 21,
#  'impact': 21,
#  'cleveland': 21,
#  'individual': 21,
#  'punjab': 21,
#  'seasons': 21,
#  'aidala': 21,
#  'hester': 21,
#  'liverpool': 21,
#  'mumbai': 21,
#  'harper': 21,
#  'shellie': 21,
#  'highway': 21,
#  'former': 21,
#  'edition': 21,
#  'trusts': 21,
#  'garibaldi': 21,
#  'return': 21,
#  'borealis': 21,
#  'solydxk': 21,
#  'membranes': 21,
#  'touring': 21,
#  'proprietary': 21,
#  'kirby': 21,
#  'bangladesh': 21,
#  'kingdoms': 21,
#  'costa': 21,
#  'access': 21,
#  'hardcore': 21,
#  'copenhagen': 21,
#  'chesney': 21,
#  'bogdanoff': 21,
#  'kurtzman': 21,
#  'senapati': 21,
#  'ellicott': 21,
#  'goodnight': 21,
#  'support': 20,
#  'bradley': 20,
#  'processors': 20,
#  'theory': 20,
#  'mohammad': 20,
#  'evaluation': 20,
#  'grave': 20,
#  'irish': 20,
#  'vietnam': 20,
#  'produced': 20,
#  'police': 20,
#  'ships': 20,
#  'pirate': 20,
#  'boats': 20,
#  'restoration': 20,
#  'docking': 20,
#  'miles': 20,
#  'indiana': 20,
#  'godfather': 20,
#  'phosphatase': 20,
#  'composers': 20,
#  'female': 20,
#  'bramlage': 20,
#  'dublin': 20,
#  'study': 20,
#  'infected': 20,
#  'belfast': 20,
#  'modern': 20,
#  'sierra': 20,
#  'munich': 20,
#  'backyard': 20,
#  'bexley': 20,
#  'erith': 20,
#  'along': 20,
#  'honda': 20,
#  'sarab': 20,
#  'ville': 20,
#  'nuding': 20,
#  ...}
