# %%
import pandas as pd
import matplotlib as plt
# %matplotlib inline

recent_grads = pd.read_csv("recent-grads.csv")

raw_data_count = recent_grads.shape[0]
recent_grads = recent_grads.dropna()
cleaned_data_count = recent_grads.shape[0]
raw_data_count, cleaned_data_count
# Out:
# (173, 172)

# %%
ax1 = recent_grads.plot(x = "Sample_size", y = "Median", kind = "scatter")
ax1.set_title("Sample_size vs. Median")

ax2 = recent_grads.plot(x = "Sample_size", y = "Unemployment_rate", kind = "scatter")
ax2.set_title("Sample_size vs. Unemployment_rate")

ax3 = recent_grads.plot(x = "Full_time", y = "Median", kind = "scatter")
ax3.set_title("Full_time vs. Median")

ax4 = recent_grads.plot(x = "ShareWomen", y = "Unemployment_rate", kind = "scatter")
ax4.set_title("ShareWomen vs. Unemployment_rate")

ax5 = recent_grads.plot(x = "Men", y = "Median", kind = "scatter")
ax5.set_title("Men vs. Median")

ax6 = recent_grads.plot(x = "Women", y = "Median", kind = "scatter")
ax6.set_title("Women vs. Median")

# %%
recent_grads['Sample_size'].hist(bins=5, range=(0,5000))

# %%
recent_grads['Median'].hist(bins=12, range=(0,120000))

# %%
recent_grads['Employed'].hist(bins=10, range=(0,5000))

# %%
recent_grads['Full_time'].hist(bins=25, range=(0,5000))
recent_grads['ShareWomen'].hist(bins=25, range=(0,5000))
recent_grads['Unemployment_rate'].hist(bins=25, range=(0,5000))
recent_grads['Men'].hist(bins=25, range=(0,5000))
recent_grads['Women'].hist(bins=25, range=(0,5000))

# %%
from pandas.tools.plotting import scatter_matrix 
scatter_matrix(recent_grads[['Sample_size', 'Median']], figsize=(10,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f626a87e0f0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f626a611c88>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f626a5dc0f0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f626a591a58>]], dtype=object)

# %%
scatter_matrix(recent_grads[['Sample_size', 'Median', "Unemployment_rate"]], figsize=(10,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f626a536390>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f626a4aef98>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f626a47e978>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f626a429da0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f626a3fe240>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f626a3b4be0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f626a37ef28>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f626a316198>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f626a309c50>]], dtype=object)

# %%
recent_grads[:10].plot.bar(x='Major', y='ShareWomen')

# %%
recent_grads[163:].plot.bar(x='Major', y='ShareWomen')

# %%
recent_grads[:10].plot.bar(x='Major', y='ShareWomen', legend=False)
